# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\Farogh\\Desktop\\New DataScience\\datascience\\Classification\\MultiClass Classification\\Iris Species\\archive (16)\\Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# plt.scatter3d (x = data["SepalLengthCm"], y= data["SepalWidthCm"], z = data["PetalLengthCm"])

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl = LabelEncoder()

# %%
lbl
# Out:
# LabelEncoder()

# %%
data["Species"] = lbl.fit_transform(data["Species"])

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
data["Species"].value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
data.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species        0.942830       0.782561     -0.419446       0.949043
#
#                PetalWidthCm   Species
# Id                 0.899759  0.942830
# SepalLengthCm      0.817954  0.782561
# SepalWidthCm      -0.356544 -0.419446
# PetalLengthCm      0.962757  0.949043
# PetalWidthCm       1.000000  0.956464
# Species            0.956464  1.000000

# %%
dataplot = sns.heatmap(data.corr(), cmap="YlGnBu", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="viridis", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="mako", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="rocket", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="Spectral", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="coolwarm", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="cividis", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="magma", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="inferno", annot=True)

# %%
dataplot = sns.heatmap(data.corr(), cmap="plasma", annot=True)

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(data.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
sns.violinplot(data, x = 'Species', y = 'PetalLengthCm', palette = ["#00d5ff", "#0d0b96", "#5c0ec9"])
# Out:
# C:\Users\Farogh\AppData\Local\Temp\ipykernel_32456\2450171469.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x = 'Species', y = 'PetalLengthCm', palette = ["#00d5ff", "#0d0b96", "#5c0ec9"])
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
# ] palette=['#FFB6C1', '#FFD700', '#00BFFF'])

# %%
sns.pairplot(data, hue = "Species")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
x = data.iloc[:, : -1]
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
y = data["Species"]
y.value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y, test_size=0.2)

# %%
print (f"x_train {x_train.shape}, x_test {x_test.shape}, y_train {y_train.shape}, y_test {y_test.shape} ")
# Out:
# x_train (120, 5), x_test (30, 5), y_train (120,), y_test (30,)

# %%
model = LogisticRegression(max_iter= 500)  # with the help of max_iter, can mangae the number of iterration 
model
# Out:
# LogisticRegression(max_iter=500)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 0, 2, 0, 0, 2, 2, 1, 2, 0, 0, 0, 2, 2, 1, 2, 1, 0, 0, 1, 0,
#        1, 0, 2, 2, 0, 1, 2, 1])

# %%
from sklearn.metrics import r2_score

# %%
# r2 = r2_score(x_train, y_train)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree = DecisionTreeClassifier()

# %%
decision_tree
# Out:
# DecisionTreeClassifier()

# %%
decision_tree.fit(x_train, y_train)

# %%
dt_pred = decision_tree.predict(x_test)

# %%
dt_pred
# Out:
# array([2, 0, 1, 0, 2, 1, 2, 1, 2, 0, 2, 0, 0, 0, 1, 0, 2, 2, 1, 0, 1, 1,
#        2, 1, 2, 1, 2, 0, 0, 2])
