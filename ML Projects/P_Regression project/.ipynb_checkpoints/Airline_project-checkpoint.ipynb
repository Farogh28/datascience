# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Airline Dataset Updated - v2.csv")

# %%
data.head(5)
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
data.isnull()
# Out:
#        Passenger ID  First Name  Last Name  Gender    Age  Nationality  \
# 0             False       False      False   False  False        False
# 1             False       False      False   False  False        False
# 2             False       False      False   False  False        False
# 3             False       False      False   False  False        False
# 4             False       False      False   False  False        False
# ...             ...         ...        ...     ...    ...          ...
# 98614         False       False      False   False  False        False
# 98615         False       False      False   False  False        False
# 98616         False       False      False   False  False        False
# 98617         False       False      False   False  False        False
# 98618         False       False      False   False  False        False
#
#        Airport Name  Airport Country Code  Country Name  Airport Continent  \
# ...

# %%
data.describe()
# Out:
#                 Age
# count  98619.000000
# mean      45.504021
# std       25.929849
# min        1.000000
# 25%       23.000000
# 50%       46.000000
# 75%       68.000000
# max       90.000000

# %% [markdown]
# # Getting the unique data from the target column

# %%
unique_status = data["Flight Status"].unique()

# %%
unique_status.sort()

# %%
unique_status
# Out:
# array(['Cancelled', 'Delayed', 'On Time'], dtype=object)

# %% [markdown]
# # Zip makes pair for the corresponding given data

# %%
lst = [0,1,2]

# %%
map_status = dict(zip(unique_status, lst))
map_status
# Out:
# {'Cancelled': 0, 'Delayed': 1, 'On Time': 2}

# %% [markdown]
# # Changing Categorical column into numerical one (Label_encoding)

# %%
# for status, status_code in map_status:
for i in range(len(data)):
    status = data.loc[i, "Flight Status"]
    if status in map_status:
         data.loc[i, "Flight Status"] = map_status[status]


    
    # if data.loc[i, "Flight Status"] == status:
    #     data.loc[i, "Flight Status"] = status_code
    # else:

# %%
data["Flight Status"].unique()
# Out:
# array([2, 1, 0], dtype=object)

# %%
x = data[["Passenger ID", "Gender", "Age", "Airport Country Code", "Departure Date", "Arrival Airport", "Flight Status"]]
x
# Out:
#       Passenger ID  Gender  Age                 Airport Name  \
# 0           ABVWIg  Female   62             Coldfoot Airport
# 1           jkXXAX    Male   62            Kugluktuk Airport
# 2           CdUz2g    Male   67       Grenoble-Isère Airport
# 3           BRS38V  Female   71    Ottawa / Gatineau Airport
# 4           9kvTLo    Male   21              Gillespie Field
# ...            ...     ...  ...                          ...
# 98614       hnGQ62    Male   85               Hasvik Airport
# 98615       2omEzh  Female   19          Ampampamena Airport
# 98616       VUPiVG    Male   65  Albacete-Los Llanos Airport
# 98617       E47NtS  Female   34               Gagnoa Airport
# 98618       8JYEcz  Female   10          Yoshkar-Ola Airport
#
#       Airport Country Code Departure Date Arrival Airport Flight Status
# 0                       US      6/28/2022             CXF             2
# 1                       CA     12/26/2022             YCO             2
# ...

# %%
data.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
# from sklearn import

# %%
len(data["Airport Name"].unique())
# Out:
# 9062

# %%
len(data["Airport Country Code"].unique())
# Out:
# 235

# %%
len(data["Arrival Airport"].unique())
# Out:
# 9024
