# %%
# dataser generation using equation

# %%
import numpy as np
import pandas as pd

# %%
x=6*np.random.rand(200,1)-3

# %%
# x

# %%
y = 0.8*x** 2 +0.9 *x + 2+ np.random.randn(200,1)

# %%
# y

# %%
new_x = np.reshape(x,-1)
# new_x
new_y= np.reshape(y, -1)

# %%
# new_y

# %%
data = pd.DataFrame({
    "feature" : new_x,
    "Output" : new_y
})

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter (x_train , y_train, color= "red", label= "Tarining Data")
plt.scatter (x_test , y_test, color= "green", label= "Tarining Data")
plt.plot (x_test,y_pred, label = "Predicted Line")
plt.legend()

# %%
# Applying Polynomial LR

# %%
data
# Out:
#       feature     Output
# 0    1.250103   3.577687
# 1    2.908188   9.507946
# 2   -2.609183   5.905499
# 3    1.553216   4.529056
# 4    0.163900   3.129611
# ..        ...        ...
# 195  0.499596   2.256327
# 196  2.601537  10.236589
# 197  2.620121  10.257261
# 198 -2.006220   3.413647
# 199  0.467362   2.520667
#
# [200 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_only = data.iloc[0:2]     # Just to print upper two rows of the dataframe

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
y_test.shape
# Out:
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit (x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
# y_pred

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred, y_test)
# Out:
# -0.8506905486326886

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 3)   # Degreee is a HyperParameter

# %%
# x_train 

x_train_new = poly.fit_transform(x_train)
# x_train_new
x_test_new = poly.fit_transform(x_test)
# x_train_new

# %%
# x_train

# %%
df= pd.DataFrame({
    "feature1": x_train_new[:,0],
    "feature2": x_train_new[:,1],
    "feature3": x_train_new[:,2],
    "output" : y_train.reshape(-1)       # reshape(-1) argument is a placeholder that automatically calculates the size of one dimension 
                                            #based on the other dimensions.   In this case, it flattens the array into a 1D vector.
    
})

df
# Out:
#      feature1  feature2  feature3     output
# 0         1.0  1.563691  2.445129   5.070376
# 1         1.0  2.601537  6.767995  10.236589
# 2         1.0  1.229922  1.512709   3.753459
# 3         1.0  2.221437  4.934782   7.832676
# 4         1.0 -2.648954  7.016957   5.795602
# ..        ...       ...       ...        ...
# 155       1.0 -2.516958  6.335078   5.794246
# 156       1.0  1.023291  1.047125   4.040115
# 157       1.0 -2.378397  5.656773   5.308861
# 158       1.0  2.696064  7.268761   8.142587
# 159       1.0  1.532528  2.348643   3.570759
#
# [160 rows x 4 columns]

# %%
x_data = df.iloc[ : , 0:3]

x_data
# Out:
#      feature1  feature2  feature3
# 0         1.0  1.563691  2.445129
# 1         1.0  2.601537  6.767995
# 2         1.0  1.229922  1.512709
# 3         1.0  2.221437  4.934782
# 4         1.0 -2.648954  7.016957
# ..        ...       ...       ...
# 155       1.0 -2.516958  6.335078
# 156       1.0  1.023291  1.047125
# 157       1.0 -2.378397  5.656773
# 158       1.0  2.696064  7.268761
# 159       1.0  1.532528  2.348643
#
# [160 rows x 3 columns]

# %%
xyz = LinearRegression ()

# %%
xyz.fit (x_train_new ,y_train)
# Out:
# LinearRegression()

# %%
df_test= pd.DataFrame({
    "feature1": x_test_new[:,0],
    "feature2": x_test_new[:,1],
    "feature3": x_test_new[:,2],
    "output" : y_test.reshape(-1)
    
})

# df_test

# %%
x_data_test = df_test.iloc [ :, 0: 3]
# x_data_test

# %%
y_pred_new = xyz.predict (x_train_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 y_pred_new = xyz.predict (x_train_new)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 3 features, but LinearRegression is expecting 4 features as input.

# %%
r2_score (y_pred_new , y_test)  # Accuracy via PLR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 r2_score (y_pred_new , y_test)  # Accuracy via PLR
#
# NameError: name 'y_pred_new' is not defined

# %%
r2_score (y_pred, y_test)
# Out:
# -0.8506905486326886

# %%
xyz.coef_
# Out:
# array([[0.        , 0.84469535, 0.80878791, 0.00409414]])

# %%
xyz.intercept_
# Out:
# array([1.98900748])

# %%
x_new = np.linspace (-3,3,200).reshape(200,1)        #This code is just to print a single cureved line
x_new_poly = poly.fit_transform(x_new)
y_new = xyz.predict (x_new_poly)

# %%
plt.scatter (x_train , y_train, color= "red", label= "Tarining Data")
plt.scatter (x_test , y_test, color= "green", label= "Tarining Data")
plt.plot (x_test,y_pred_new, label = "Predicted Line")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 plt.scatter (x_train , y_train, color= "red", label= "Tarining Data")
#       2 plt.scatter (x_test , y_test, color= "green", label= "Tarining Data")
# ----> 3 plt.plot (x_test,y_pred_new, label = "Predicted Line")
#       4 plt.legend()
#
# NameError: name 'y_pred_new' is not defined

# %%
plt.scatter (x_train , y_train, color= "red", label= "Tarining Data")
plt.scatter (x_test , y_test, color= "green", label= "Tarining Data")
plt.plot (x_new,y_new, label = "Predicted Line")
plt.legend()

# %%
from sklearn.preprocessing import StandardScaler

# %%
def polynomia_degree_checker (degree):
    x_new = np.linspace (-3,3,200).reshape(200,1)        #This code is just to print a single cureved line
    x_new_poly = poly.fit_transform(x_new)

    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

    poly = PolynomialFeatures(degree = degree)
    x_train_new = poly.fit_transform(x_train)
    # x_train_new
    x_test_new = poly.fit_transform(x_test)
    # x_tr#in_new
    
    std_scaler = StandardScaler     #Standard Scaler instance
    lin_reg = LinearRegression 
    
    xyz.fit (x_train_new ,y_train)

    df_test= pd.DataFrame({
    "feature1": x_test_new[:,0],
    "feature2": x_test_new[:,1],
    "feature3": x_test_new[:,2],
    "output" : y_test.reshape(-1)
    
    })

    x_data_test = df_test.iloc [ :, 0: 3]
    y_pred_new = xyz.predict (x_data_test)
    r2_score (y_pred_new , y_test)  # Accuracy via PLR

    x_new = np.linspace (-3,3,200).reshape(200,1)        #This code is just to print a single cureved line
    x_new_poly = poly.fit_transform(x_new)
    y_new = xyz.predict (x_new_poly)


    plt.scatter (x_train , y_train, color= "red", label= "Tarining Data")
    plt.scatter (x_test , y_test, color= "green", label= "Tarining Data")
    plt.plot (x_new,y_new, label = "Predicted Line")
    plt.legend()

# %%
# polynomia_degree_checker(2)

# %%
from sklearn.pipeline import Pipeline

# %%
def polynomial_regression(degree):
    X_new=np.linspace(-3, 3, 100).reshape(100, 1)
    X_new_poly = poly.transform(X_new)

    polybig_features = PolynomialFeatures(degree=degree, include_bias=False)
    std_scaler = StandardScaler()
    lin_reg = LinearRegression()
    polynomial_regression = Pipeline([
            ("poly_features", polybig_features),
            ("std_scaler", std_scaler),
            ("lin_reg", lin_reg),
        ])
    polynomial_regression.fit(x, y)
    y_newbig = polynomial_regression.predict(X_new)
    plt.plot(X_new, y_newbig,'r', label="Degree " + str(degree), linewidth=2)

    plt.plot(x_train, y_train, "b.", linewidth=3)
    plt.plot(x_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-3, 3, 0, 10])
    plt.show()

# %%
polynomial_regression(3)

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate some example data (you'll replace this with your own dataset)
X = np.random.rand(100, 1)  # Example feature (1D array)
y = 2 * X**2 + 3 * X + 1 + np.random.randn(100, 1)  # Example target (with noise)

# Create polynomial features (degree=2 for quadratic regression)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit the model
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)

# Predictions
X_new = np.linspace(0, 1, 100).reshape(-1, 1)
X_new_poly = poly.transform(X_new)
y_pred = lin_reg.predict(X_new_poly)

# Plot the results
plt.scatter(X, y, label="Data points")
plt.plot(X_new, y_pred, color='r', label="Polynomial Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Polynomial Regression Example")
plt.legend()
plt.show()
