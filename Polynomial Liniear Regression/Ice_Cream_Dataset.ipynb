# %%
import pandas as pd #To load data 
import numpy as np #to reshape 
import matplotlib.pyplot as plt  #for visual representation
from sklearn.linear_model import LinearRegression #to train the model 
from sklearn.model_selection import train_test_split  #To divide
# To modify and to extract polynomial features
from sklearn.preprocessing import PolynomialFeatures

# %%
# Loading data
data = pd.read_csv ("C:\\Users\\Farogh\\Desktop\\learning\\Polynomial Liniear Regression\\Ice_cream selling data.csv")

# %%
data.shape

# data.shape
# Out:
# (49, 2)

# %%
#Ploting data

# %%
plt.scatter (data["Temperature (°C)"],data["Ice Cream Sales (units)"] )

# %%
x=data ["Temperature (°C)"]
y=data ["Ice Cream Sales (units)"]

# %%
x = data.iloc [:, : -1].values 
y= data ["Ice Cream Sales (units)"].values

# %%
x.shape
# Out:
# (49, 1)

# %%
y.shape
# Out:
# (49,)

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y , test_size = 0.2)

# %%
x_train.shape
# Out:
# (39, 1)

# %%
x_test.shape
# Out:
# (10, 1)

# %%
y_train.shape
# Out:
# (39,)

# %%
y_test.shape
# Out:
# (10,)

# %%
plt.scatter (x_train,y_train, color = "red", label = "Training data")
plt.scatter (x_test,y_test, color = "green", label = "Teseting data")
plt.legend()
plt.xlabel("Temperature")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
# x_train

# %%
# x

# %%
poly = PolynomialFeatures(degree = 2)

# For single column (as degree is set as 2)= x == x0 | x1 | x2
# For single column (as degree is set as 3)= x == x0 | x1 | x2 | x3

# %%
# Reshaping data 1D to 2D
# x_train_reshaped = x_train.values
# x_train_reshaped

# %%
x_train_new = poly.fit_transform(x_train)

# %%
x_new = np.linspace(-4, 4, 49).reshape(49, 1)
x_new_poly = poly.fit_transform(x_new)
y_new = model.predict(x_new_poly)

# %%
plt.scatter (x_train,y_train, color = "red", label = "Training data")
plt.scatter (x_test,y_test, color = "green", label = "Teseting data")
plt.plot (x_new,y_new, label = "Predicted Line")
plt.legend()

# %%
x_train_new.shape
# Out:
# (39, 3)

# %%
# x_test_reshaped= x_test.values  # transform data into numpy array
# x_test_reshaped

# %%
x_test_new = poly.fit_transform(x_test)
x_test_new
# Out:
# array([[ 1.00000000e+00,  4.13353379e+00,  1.70861016e+01],
#        [ 1.00000000e+00,  3.70405744e+00,  1.37200415e+01],
#        [ 1.00000000e+00,  1.85055193e+00,  3.42454243e+00],
#        [ 1.00000000e+00, -3.38952856e-02,  1.14889038e-03],
#        [ 1.00000000e+00, -3.10844012e+00,  9.66239999e+00],
#        [ 1.00000000e+00,  2.83176021e+00,  8.01886589e+00],
#        [ 1.00000000e+00, -1.66034773e+00,  2.75675458e+00],
#        [ 1.00000000e+00, -3.45571170e+00,  1.19419433e+01],
#        [ 1.00000000e+00,  1.02418081e+00,  1.04894634e+00],
#        [ 1.00000000e+00, -1.32637898e+00,  1.75928121e+00]])

# %%
model = LinearRegression()

# %%
model.fit(x_train_new, y_train)   # y_train ko convert kr ke 1D me kra via using []
# Out:
# LinearRegression()

# %%
x_train_new.shape

# x_train_new
# Out:
# (39, 3)

# %%
# Now finding prediction's

# %%
x_test_new
# Out:
# array([[ 1.00000000e+00,  4.13353379e+00,  1.70861016e+01],
#        [ 1.00000000e+00,  3.70405744e+00,  1.37200415e+01],
#        [ 1.00000000e+00,  1.85055193e+00,  3.42454243e+00],
#        [ 1.00000000e+00, -3.38952856e-02,  1.14889038e-03],
#        [ 1.00000000e+00, -3.10844012e+00,  9.66239999e+00],
#        [ 1.00000000e+00,  2.83176021e+00,  8.01886589e+00],
#        [ 1.00000000e+00, -1.66034773e+00,  2.75675458e+00],
#        [ 1.00000000e+00, -3.45571170e+00,  1.19419433e+01],
#        [ 1.00000000e+00,  1.02418081e+00,  1.04894634e+00],
#        [ 1.00000000e+00, -1.32637898e+00,  1.75928121e+00]])

# %%
y_test
# Out:
# array([27.69838335, 17.84395652,  4.8579878 ,  0.89760319, 22.63540128,
#        12.56823739, 12.61518115, 30.00113848,  2.31380636, 10.95773134])

# %%
# Formula 

# y= b0 + b1x1 + b2x2 +b3x3

# %%
x= model.coef_
x
# Out:
# array([ 0.        , -0.57599937,  1.87719048])

# %%
model.intercept_
# Out:
# 2.8242999304669016

# %%
import joblib

# %%
joblib.dump (model, "icecream_selling_unit_predictor.joblib")
# Out:
# ['icecream_selling_unit_predictor.joblib']

# %%
# Remaining work in VS Code for Frontend
