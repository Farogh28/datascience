# %%
# -pip install seaborn

# %%
pip install --upgrade matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB 1.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/8.0 MB 5.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.0 MB 11.4 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/8.0 MB 13.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.0 MB 13.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.0 MB 9.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.2/8.0 MB 11.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 12.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/8.0 MB 12.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 13.2 MB/s eta 0:00:01
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
fmri = sns.load_dataset("fmri")   # fmri is builtin dataset
fmri.head()
# fmri.tail()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = "timepoint", y= "signal", data = fmri)
plt.show()

# %%
# HUE - Visualize data in one plot

# %%
sns.lineplot(x = "timepoint", y= "signal", data = fmri, hue = "event")
plt.show()

# %%
# STYLE a line

# %%
sns.lineplot(x = "timepoint", y= "signal", data = fmri, hue = "event", style = "event")
plt.show()

# %%
# MARKERS --  To add markers on the line

# %%
sns.lineplot(x = "timepoint", y= "signal", data = fmri, hue = "event", style = "event", markers = True)
plt.show()

# %% [markdown]
# # BAR PLOTS

# %%
import pandas as pd

# %%
pokemon = pd.read_csv("pokemon.csv")
pokemon.head()
# pokemon.describe()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
sns.barplot(x = "is_legendary", y= "speed", data = pokemon )
plt.show()

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", data = pokemon )
# Out:
# <Axes: xlabel='is_legendary', ylabel='weight_kg'>

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", hue = "generation" ,data = pokemon )
plt.show()

# %% [markdown]
# # PALETTE attribute

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", hue = "generation" ,data = pokemon , palette="Blues_d" )
plt.show()

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", hue = "generation" ,data = pokemon , palette="rocket" )
plt.show()

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", hue = "generation" ,data = pokemon , palette="vlag" )
plt.show()

# %%
# Or can directly assing a single color to whole plot

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", hue = "generation" ,data = pokemon , color = "red" )
plt.show()
# Out:
# C:\Users\Farogh\AppData\Local\Temp\ipykernel_13524\1885180799.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x = "is_legendary", y= "weight_kg", hue = "generation" ,data = pokemon , color = "red" )

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x = "is_legendary", y= "weight_kg", data = pokemon , color = "orange")
# Out:
# <Axes: xlabel='is_legendary', ylabel='weight_kg'>

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(x = "SepalLengthCm", y = "PetalLengthCm", data = iris)
plt.show()

# %% [markdown]
# # Now adding color and adding style

# %%
plt.scatter(x = "SepalLengthCm", y = "PetalLengthCm", hue= "Species", style="Species", data = iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.scatter(x = "SepalLengthCm", y = "PetalLengthCm", hue= "Species", style="Species", data = iris)
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
# ...

# %%
plt.scatter(x = "SepalLengthCm", y = "PetalLengthCm", data = iris, hue = "PetalLengthCm")
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd

# # Sample DataFrame
# iris = pd.DataFrame({
#     'SepalLengthCm': [5.1, 4.9, 4.7, 4.6, 5.0],
#     'PetalLengthCm': [1.4, 1.4, 1.3, 1.5, 1.4]
# })

# sns.scatterplot(x="SepalLengthCm", y="PetalLengthCm", hue="PetalLengthCm", data=iris)
# plt.show()

# %% [markdown]
# # HISTOGRAM or a DISTRIBUTION PLOT

# %%
diamond = pd.read_csv("diamonds.csv")

# %%
diamond.head()

# %%
# Distribution plot - is used for continous numerical values,

# %%
sns.distplot(diamond['price'])
plt.show()

# %%
""" if want only frequency curve without histogram   {hist = False}"""

# %%
sns.distplot(diamond['price'], hist = False)
plt.show()

# %% [markdown]
# # Color

# %%
sns.distplot(diamond['price'], color = "green")
plt.show()

# %%
# Dist plot without frequency curve

# %%
""" KDE = False """

# %%
sns.distplot(diamond['price'], kde = False )
plt.show()

# %%
sns.distplot(diamond['price'], kde = False, bins = 10 )
plt.show()

# %% [markdown]
# # Plots the graph VERTICALLY

# %%
sns.distplot(diamond['price'], kde = False , vertical= True)
plt.show()

# %% [markdown]
# # JOINT PLOT - combination of Scatter and Histogram plot

# %%
iris.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
sns.jointplot(x = "SepalLengthCm", y= "PetalLengthCm", data = iris)

# %%
sns.jointplot(x = "SepalLengthCm", y= "PetalLengthCm", data = iris, color = "olive")

# %% [markdown]
# # kind` must be one of ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid']

# %%
sns.jointplot(x = "SepalLengthCm", y= "PetalLengthCm", data = iris, color = "olive", kind = "reg")

# %% [markdown]
# # BOX PLOT

# %%
# Box plot shows us how does a categorical value change along with a numerical value

# %%
churn = pd.read_csv("Customer-Churn.csv")

# %%
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.boxenplot(x = "Churn", y= "tenure", data = churn )
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
# sns.boxplot(x = "tenure", y= "Churn", data = churn )

# %%
sns.boxplot (x = "InternetService", y= "MonthlyCharges", data= churn)
# Out:
# <Axes: xlabel='InternetService', ylabel='MonthlyCharges'>

# %%
# sns.boxplot (x = "Contract", y= "tenure", data= churn, palette="tenure")

# %%
""" To Change Line width"""

# %%
sns.boxplot (x = "Contract", y= "tenure", data= churn, linewidth= 3)
# Out:
# <Axes: xlabel='Contract', ylabel='tenure'>

# %%
sns.boxplot (x = "Contract", y= "tenure", data= churn, linewidth= 3, linecolor= "red")
# Out:
# <Axes: xlabel='Contract', ylabel='tenure'>

# %%
""" ORDER Attribute """

# %%
sns.boxplot (x = "Contract", y= "tenure", data= churn, order= ["Two year", "Month-to-month", "One year Contract"] )
# Out:
# <Axes: xlabel='Contract', ylabel='tenure'>

# %%
sns.boxplot (x = "Contract", y= "tenure", data= churn, order= ["Two year", "Month-to-month", "One year Contract"], hue = "PaymentMethod")
# Out:
# <Axes: xlabel='Contract', ylabel='tenure'>

# %%
battle = pd.read_csv("battles.csv")

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
""" Step to change a Column name """

# %%
battle.rename(columns={'attacker_1' : 'primary_defender'}, inplace= True)

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king primary_defender  \
# 0  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 1  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 2  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 3                Robb Stark  Joffrey/Tommen Baratheon            Stark
# 4                Robb Stark  Joffrey/Tommen Baratheon            Stark
#
#   attacker_2 attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle['attacker_king'].value_counts()
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: count, dtype: int64

# %%
how many times the king attacked

# %%
battle['location'].value_counts()
# Out:
# location
# Riverrun                                3
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
sns.set(rc = {'figure.figsize' : (13,5)})  # Setting size
sns.barplot(x = "defender_king", y= "defender_size", data = battle)
# Out:
# <Axes: xlabel='defender_king', ylabel='defender_size'>

# %%
sns.set(rc = {'figure.figsize' : (13,5)})  # Setting size
sns.barplot(x = "attacker_king", y= "attacker_size", data = battle)

# %%
sns.countplot(x = battle['attacker_king'], hue = battle ['battle_type'])  # hue returns the color as per battle and labled as Battle_type
# Out:
# <Axes: xlabel='attacker_king', ylabel='count'>

# %% [markdown]
# # Color PALETTE

# %%
import seaborn as sns
from matplotlib import pyplot as plt

tips = sns.load_dataset("tips") # some example data
palette = ["#F72585", "#7209B7", "#3A0CA3", "#4361EE", "#4CC9F0"]
sns.set()
# or: sns.set_palette(palette), then the palette argument below is not needed
sns.catplot(x="day", y="total_bill", data=tips, palette=palette)
plt.tight_layout()
# Out:
# C:\Users\Farogh\AppData\Local\Temp\ipykernel_13524\4271440023.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="day", y="total_bill", data=tips, palette=palette)
# C:\Users\Farogh\AppData\Local\Temp\ipykernel_13524\4271440023.py:8: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.catplot(x="day", y="total_bill", data=tips, palette=palette)

# %%
a = [1,2,3,4,5,6,7,8]
c = [2,3,4,5,3,3,5,6]

df = pd.DataFrame({"a": a, "c" : c})

# or 

df = pd.DataFrame({"a": [1,2,3,4,5,6,7,8], "c": [2,3,4,5,3,3,5,6]})


sns.lineplot(x = "a", y= "c", data = df)

plt.show()   # To remove title  from graph

# %%
plt.plot(a, c)

# %%
y = sns.load_dataset("penguins")

# %%
y
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y)

plt.show()   # To remove title  from graph

# %%
help("hue")
# Out:
# No Python documentation found for 'hue'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y, hue = "sex")

# plt.show()   # To remove title  from graph
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y, hue = "sex", style = "sex")

plt.show()   # To remove title  from graph

# %%
sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y, hue = "sex", size = 40)

plt.show()   # To remove title  from graph

# %%
sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y, hue = "sex", palette= "cool_r") # for color bar we use palette

plt.show()   # To remove title  from graph

# %%
# sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y, hue = "sex", palette= ) # for color bar we use palette

plt.show()   # To remove title  from graph

# %%
# USING - -- - - - Marker

# %%
sns.lineplot(x = "bill_length_mm", y= "bill_depth_mm", data = y, hue = "sex", palette= "cool_r", markers = ["o", ">"],
            ) 

plt.show()   # To remove title  from graph

# %% [markdown]
# # Histogram Plots

# %%
functions used to plot is "sns.distplot(df[])"
# Out:
#   Cell In[72], line 1
#     functions used to plot is "sns.distplot(df[])"
#               ^
# SyntaxError: invalid syntax

# %%
import libraries
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 import libraries
#
# ModuleNotFoundError: No module named 'libraries'

# %%
load dataset as a string without extension
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3909, in InteractiveShell.find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3908 try:                                              # User namespace
# -> 3909     codeobj = eval(target, self.user_ns)
#    3910 except Exception as e:
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 get_ipython().run_line_magic('load', 'dataset as a string without extension')
#
# ...

# %%
y
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.distplot(y["bill_length_mm"])
plt.show()
# Out:
# C:\Users\Farogh\AppData\Local\Temp\ipykernel_13524\1437553.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y["bill_length_mm"])

# %%
sns.displot(y["flipper_length_mm"])

# %%
sns.displot(y["flipper_length_mm"], bins = [170,180,190,200, 210,220,230,240])   # to organize data bars

# %%
sns.displot(y["flipper_length_mm"], bins = [170,180,190,200, 210,220,230,240], kde = True)   # Kernel density estimate to plot line

# %%
sns.displot(y["flipper_length_mm"], bins = [170,180,190,200, 210,220,230,240], rug = "True")

# %%
sns.displot(y["flipper_length_mm"], bins = [170,180,190,200, 210,220,230,240], color = "green", kde = True)

# %%
sns.displot(y["flipper_length_mm"], log_scale= True)    # Log scale
