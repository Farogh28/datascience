# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as  plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("C:\\Users\\Farogh\\Desktop\\learning\\placement.csv")
data
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
data.shape
# Out:
# (200, 2)

# %%
x= data.iloc[:, 0:1]

# %%
y= data ["package"]

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
model = LinearRegression()   # Pre define algorithm, and here we are creating instance of it.

# %%
model.fit (x_train, y_train)    # Model ko train krne ke liye data pass kiya
# Out:
# LinearRegression()

# %%
y_pred = model.predict (x_test)
y_pred
# Out:
# array([3.68218147, 3.09459205, 2.48373175, 3.11786291, 2.92587825,
#        2.15793959, 2.40228371, 2.33828882, 3.00150857, 2.78625304,
#        3.77526495, 3.2167641 , 2.62917467, 3.74035865, 3.69963463,
#        3.1818578 , 2.33828882, 4.35703666, 3.33893616, 3.22258182,
#        2.40228371, 2.81534162, 3.39711334, 3.5541917 , 2.64662783,
#        3.60073344, 2.46046088, 3.54255626, 3.85089527, 2.60008609,
#        3.72290549, 2.96660227, 2.39646599, 3.07713889, 2.9782377 ,
#        2.20448132, 2.97241999, 1.76233482, 4.51411502, 3.36802475])

# %%
plt.scatter (x_train , y_train, color = ("red"), label = "This is training data")
plt.scatter (x_test , y_test , color = "green", label = "This is testing data")
plt.plot (x_test,y_pred) 
plt.legend()
plt.xlabel = ("CGPA")
plt.ylabel = ("Package")

# %%
data.corr()
# Out:
#              cgpa   package
# cgpa     1.000000  0.880692
# package  0.880692  1.000000

# %%
model.score(x_test, y_test)
# Out:
# 0.7213566625782563

# %%
# y_pred.predict(7)

# %%
import joblib

# %%
joblib.dump(model, "SLR_pred.joblib")
# Out:
# ['SLR_pred.joblib']

# %%
model.coef_
# Out:
# array([0.58177171])

# %%
model.intercept_
# Out:
# -1.0592579838410128

# %%
# Steps to do 
# Describe()
# Info()
# Corelation (corr())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Salary_Data.csv")
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,1]

# x = x.reshape(-1, 1)
# y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# y = mx + b

m = model.coef_
b = model.intercept_

y = m*7.9 + b    #7.9	101302.0
print(y)
# Out:
# [100402.58629235]

# %%
xx = np.array(7.9).reshape(-1, 1)
# y = y.reshape(-1, 1)

model.predict(xx)
# Out:
# C:\Users\Farogh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([100402.58629235])

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([103255.01242447, 116566.33437436,  81386.41207821,  53812.95946772,
#         39550.82880712, 110861.48211012])

# %%
plt.scatter(x,y)
plt.plot(x_test,y_pred)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9593942499816251
