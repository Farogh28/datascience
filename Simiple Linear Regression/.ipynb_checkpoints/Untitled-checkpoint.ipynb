# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Salary_Data.csv")
print(data.shape)
data.columns
# Out:
# (30, 2)
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
x = data.iloc[:,:-1]
x.head(4)
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0

# %%
y = data["Salary"]
y.head(4)
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=52)

# %%
print (f"Shape of x_train {x_train.shape}, Shape of Y_train {y_train.shape}, Shape of x_test and y_test {x_test.shape, y_test.shape}")
# Out:
# Shape of x_train (24, 1), Shape of Y_train (24,), Shape of x_test and y_test ((6, 1), (6,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 89877.95493362,  71960.95964568,  55929.96386174,  39898.9680778 ,
#        115338.94823753,  55929.96386174])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter (x_train, y_train, color = "black")
plt.scatter (x_test, y_test, color = "yellow")
plt.plot (x_test, y_pred )
