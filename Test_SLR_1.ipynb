# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
df = pd.read_csv ("placement.csv")

# %%
df.shape
# Out:
# (200, 2)

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
 # (it hepls to display the graph with in the notebook rather then a seprate window)

# %%
# %matplotlib inline  
plt.xlabel ('CGPA')
plt.ylabel ('Package')
plt.scatter(df.cgpa,df.package, color = "red", marker = ".")

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['cgpa']],df.package)
# Out:
# LinearRegression()

# %%
# reg.predict(3)

# %%
cgpa = np.array(7)

# %%
xyz= cgpa.reshape(1,-1)

# %%
temp = reg.predict(xyz)
# Out:
# C:\Users\Farogh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
temp
# Out:
# array([3.00146112])
