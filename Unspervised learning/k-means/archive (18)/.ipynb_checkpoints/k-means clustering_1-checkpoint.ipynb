# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student_clustering.csv")

# %%
data
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
# data.info
print (f"Number of Rows {data.shape[0]}")     # 0 for rows
print (f"Number of Columns {data.shape[1]}")   # 1 for columns
# Out:
# Number of Rows 200
# Number of Columns 2

# %%
plt.scatter(data["cgpa"], data["iq"])

# %%
# Applying Elbow method

# %%
# WCSS applying

# %%
from sklearn.cluster import KMeans # k-mean is an algorithm so K and M is inn capital form

# %%
# WCSS calculate to know how many cluster is going to form

# %%
WCSS = []

# %%
# for i in range (1,11):
km = KMeans(n_clusters = 1)    #(paramenter is used in k means is n_cluster )

km.fit_predict(data)

km.inertia_   #inertia is a paramnter or a wcss
# Out:
# 29957.898288000004

# %%
km = KMeans(n_clusters = 2)    #(paramenter is used in k means is n_cluster )

km.fit_predict(data)

km.inertia_   #inertia is a paramnter or a wcss
# Out:
# 4184.14127

# %%
km = KMeans(n_clusters = 3)    #(paramenter is used in k means is n_cluster )

km.fit_predict(data)

km.inertia_   #inertia is a paramnter or a wcss
# Out:
# 2364.005583420084

# %%
km = KMeans(n_clusters = 4)    #(paramenter is used in k means is n_cluster )

km.fit_predict(data)

km.inertia_   #inertia is a paramnter or a wcss
# Out:
# 681.9696600000002

# %%
km = KMeans(n_clusters = 5)    #(paramenter is used in k means is n_cluster )

km.fit_predict(data)

km.inertia_   #inertia is a paramnter or a wcss
# Out:
# 599.4812142280701

# %%
# back to the loop

# %%
WCSS = []

# %%
for i in range (1,11):
    km = KMeans(n_clusters = i)    
    km.fit_predict(data)
    WCSS.append(km.inertia_)

# %%
WCSS
# Out:
# [29957.898288000004,
#  4184.14127,
#  2503.3975810000006,
#  681.9696600000002,
#  563.7685674520716,
#  461.5723959208411,
#  376.6965473108638,
#  242.25461777981252,
#  202.82408477012285,
#  178.8841237843855]

# %%
plt.plot (range(1,11), WCSS, color ="red", linewidth = 2, label = "Elbow curve", 
          marker = ".", ms = "10", mfc = "yellow", mec = "green")
plt.legend()
    
for i in range (1,5):        # to print, to show after how many cluster the value is coming
    plt.annotate(xy = (i, WCSS[i-1]), text = f"Centroid : {i}, WCSS: {WCSS[i-1]}")

# %%
km_new = KMeans(n_clusters= 4)

# %%
km_new
# Out:
# KMeans(n_clusters=4)

# %%
# dataframe -----> to numpy convert

# %%
# df_array = data.iloc[:,:]   # all rows and all columns

# df_array = data.iloc[:,:],values   Convert into numpy via .values

# %%
df_array = data.iloc[:,:].values

# %%
df_array
# Out:
# array([[  5.13,  88.  ],
#        [  5.9 , 113.  ],
#        [  8.36,  93.  ],
#        [  8.27,  97.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  8.41,  98.  ],
#        [  8.8 , 115.  ],
#        [  5.79, 110.  ],
#        [  8.09,  94.  ],
#        [  4.6 ,  86.  ],
#        [  6.1 , 110.  ],
#        [  8.16,  97.  ],
#        [  5.  ,  88.  ],
#        [  5.71, 108.  ],
#        [  8.31,  95.  ],
#        [  5.5 , 111.  ],
#        [  7.87,  91.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  7.47,  98.  ],
#        [  4.86,  86.  ],
#        [  7.78,  92.  ],
#        [  4.78,  87.  ],
#        [  4.96,  88.  ],
#        [  7.93,  98.  ],
#        [  4.86,  87.  ],
#        [  9.18, 119.  ],
#        [  8.04,  94.  ],
#        [  5.43, 106.  ],
#        [  8.86, 117.  ],
#        [  6.01, 112.  ],
#        [  8.83, 118.  ],
#        [  5.32, 106.  ],
#        [  7.77,  96.  ],
#        [  8.  ,  96.  ],
#        [  8.56, 118.  ],
# ...

# %%
my_clsuter = km_new.fit_predict(df_array)

# %%
my_clsuter.shape
# Out:
# (200,)

# %%
my_clsuter
# Out:
# array([1, 2, 3, 3, 2, 2, 3, 0, 2, 3, 1, 2, 3, 1, 2, 3, 2, 3, 2, 2, 3, 1,
#        3, 1, 1, 3, 1, 0, 3, 2, 0, 2, 0, 2, 3, 3, 0, 2, 1, 2, 1, 3, 3, 1,
#        0, 0, 3, 2, 0, 2, 1, 1, 0, 3, 0, 2, 2, 0, 2, 0, 2, 3, 3, 0, 1, 0,
#        3, 1, 2, 3, 2, 0, 3, 1, 2, 0, 2, 0, 1, 3, 3, 0, 2, 1, 0, 1, 0, 2,
#        0, 2, 0, 0, 3, 1, 3, 3, 0, 3, 1, 0, 2, 1, 1, 0, 1, 1, 3, 1, 0, 0,
#        3, 0, 2, 2, 3, 0, 3, 2, 0, 1, 1, 2, 3, 0, 3, 1, 3, 2, 1, 3, 3, 2,
#        1, 1, 2, 0, 2, 1, 3, 3, 3, 1, 2, 1, 1, 0, 1, 0, 2, 1, 0, 1, 0, 0,
#        1, 3, 2, 0, 2, 3, 1, 0, 2, 3, 0, 1, 2, 1, 1, 0, 0, 2, 0, 1, 1, 3,
#        0, 2, 1, 0, 0, 2, 2, 2, 3, 1, 3, 3, 0, 2, 3, 3, 1, 1, 3, 1, 0, 2,
#        2, 0])

# %%
data[my_clsuter == 0]
# Out:
#      cgpa   iq
# 7    8.80  115
# 27   9.18  119
# 30   8.86  117
# 32   8.83  118
# 36   8.56  118
# 44   8.96  116
# 45   8.78  116
# 48   8.45  119
# 52   8.79  116
# 54   8.81  115
# 57   8.88  115
# 59   9.07  117
# 63   8.92  118
# 65   8.75  113
# 71   8.71  116
# 75   8.86  118
# 77   9.30  117
# 81   9.01  121
# 84   8.97  116
# 86   9.00  117
# 88   8.76  117
# 90   8.78  117
# 91   9.23  114
# 96   9.03  118
# 99   9.13  118
# 103  8.91  119
# 108  8.98  118
# 109  9.03  118
# 111  8.86  117
# 115  8.89  118
# 118  8.97  117
# 123  8.72  119
# 135  8.93  118
# 145  8.58  118
# 147  8.94  117
# 150  8.60  117
# 152  8.77  117
# 153  8.81  116
# 157  8.54  118
# 161  8.97  119
# 164  8.91  117
# 169  8.68  119
# 170  9.06  120
# 172  8.90  117
# 176  8.94  115
# 179  8.91  115
# 180  8.91  117
# 188  8.95  116
# 196  8.57  118
# 199  8.82  117

# %%
df_array[my_clsuter == 0,0]   # when we pass 0, 0 then it show on 0 cluster with the cgpa value
# Out:
# array([8.8 , 9.18, 8.86, 8.83, 8.56, 8.96, 8.78, 8.45, 8.79, 8.81, 8.88,
#        9.07, 8.92, 8.75, 8.71, 8.86, 9.3 , 9.01, 8.97, 9.  , 8.76, 8.78,
#        9.23, 9.03, 9.13, 8.91, 8.98, 9.03, 8.86, 8.89, 8.97, 8.72, 8.93,
#        8.58, 8.94, 8.6 , 8.77, 8.81, 8.54, 8.97, 8.91, 8.68, 9.06, 8.9 ,
#        8.94, 8.91, 8.91, 8.95, 8.57, 8.82])

# %%
df_array[my_clsuter == 0,1]
# Out:
# array([115., 119., 117., 118., 118., 116., 116., 119., 116., 115., 115.,
#        117., 118., 113., 116., 118., 117., 121., 116., 117., 117., 117.,
#        114., 118., 118., 119., 118., 118., 117., 118., 117., 119., 118.,
#        118., 117., 117., 117., 116., 118., 119., 117., 119., 120., 117.,
#        115., 115., 117., 116., 118., 117.])

# %%
plt.scatter (df_array[my_clsuter == 0,0], df_array [my_clsuter == 0,1], color = "red", label = "Cluster 0")
plt.scatter (df_array[my_clsuter == 1,0], df_array [my_clsuter == 1,1], color = "green", label = "Cluster 1")
plt.scatter (df_array[my_clsuter == 2,0], df_array [my_clsuter == 2,1], color = "black", label = "Cluster 2")
plt.scatter (df_array[my_clsuter == 3,0], df_array [my_clsuter == 3,1], color = "blue", label = "Cluster 3")
plt.legend()
plt.xlabel = ("CGPA")
plt.ylabel = ("IQ")
