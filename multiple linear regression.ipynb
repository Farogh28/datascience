# %%
import pandas as pd
import numpy as np
import plotly.express as ex

# %%
from sklearn.datasets import make_regression

# %%
# x,y = make_regression (n_samples=200, n_features = 2, n_informative =2 , n_target=1)

# %%
x, y = make_regression(n_samples=200, n_features=2, n_informative=2, n_targets=1)

# %%
x
# Out:
# array([[ 1.0449149 , -1.74219728],
#        [-0.5176605 , -0.58961601],
#        [-0.67461538,  0.66996446],
#        [-0.87400743, -0.35346972],
#        [ 0.02855011, -2.07200332],
#        [-1.13255059, -0.14385849],
#        [-0.40152367,  0.37823604],
#        [ 0.71697734,  0.83128273],
#        [ 1.14317315,  1.65371417],
#        [-0.00282219, -2.43421903],
#        [ 0.40645469, -1.86713491],
#        [-0.26161774,  0.49545305],
#        [-0.7653632 ,  0.53249566],
#        [ 0.15819188, -0.77009079],
#        [ 0.24275412,  0.86537635],
#        [-0.77053629, -0.47818529],
#        [-0.32415823,  0.09175219],
#        [ 0.71897068, -2.62196448],
#        [ 0.95659105,  1.20675908],
#        [ 0.10390521, -1.35031572],
#        [-1.10596523,  0.2687731 ],
#        [-0.43099974,  1.47921317],
#        [ 0.74965498,  0.27033965],
#        [ 1.22448835,  1.28888597],
#        [ 0.82761111, -2.21318341],
#        [-0.35253683,  1.70037142],
#        [-1.13649153,  0.61248214],
# ...

# %%
data_dict = {'Feature1': x[:, 0], 'Feature2': x[:, 1], 'Target': y}

# %%
df = pd.DataFrame(data_dict)

# %%
df
# Out:
#      Feature1  Feature2      Target
# 0    1.044915 -1.742197  -85.964098
# 1   -0.517660 -0.589616  -34.736056
# 2   -0.674615  0.669964   31.290853
# 3   -0.874007 -0.353470  -24.474660
# 4    0.028550 -2.072003 -110.101208
# ..        ...       ...         ...
# 195 -1.297537 -0.076335  -12.466696
# 196 -0.050913 -0.214950  -11.770849
# 197  0.415847 -0.184856   -7.146002
# 198 -0.188065 -0.019709   -2.267076
# 199  0.612059  0.260023   17.804252
#
# [200 rows x 3 columns]

# %%
data = pd.read_csv ("Salary_dataset.csv")

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
# data= data.drop(" "axis=1)

# %%
#  Command line below, helps to delete the unnamed coloumn of the dataset.

# %%
data.drop(data.columns[data.columns.str.contains('unnamed', case=False)], axis=1, inplace=True)

# %%
# 0 is he indexing or place of the unnamed column

# %%
data= data.drop(data.columns[[0]],
               axis = 1)

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0
